# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonam675/ML-and-GenAI-with-Python-2026/blob/main/Ass_1_Sonam__196.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Base = 10
Height = 15

Area = 1/2*(Base*Height)

print("Area : ", Area)
# Out:
# Area :  75.0

# %%
P = 15
R = 20
T = 14

SI = ( P*R*T) / 100

print("SI : " , SI)
# Out:
# SI :  42.0

# %%
C = 276

f = ( C*9/5 )+ 32

print("temperature in F : " , f)
# Out:
# temperature in F :  528.8

# %%
a = 5
b = 7
c = 3

avg = (a+b+c)/3

print("Average of the Number is : " , avg)
# Out:
# Average of the Number is :  5.0

# %%
a = 6

sq = a*a
cube = a*a*a
print("Square of the number is : " , sq)
print("Cube of the number is : " , cube)
# Out:
# Square of the number is :  36
# Cube of the number is :  216

# %%
# Input two numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

# Swapping without using a third variable
a = a + b
b = a - b
a = a - b

# Display result
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 5
# Enter second number: 7
# After swapping:
# a = 7
# b = 5

# %%
# Student Report Program

# Taking student details
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

# Taking marks of 5 subjects
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))
english = int(input("Enter English marks: "))
computer = int(input("Enter Computer marks: "))
hindi = int(input("Enter Hindi marks: "))

# Calculating total marks
total = maths + science + english + computer + hindi

# Calculating percentage
percentage = total / 5

# Displaying student report
print("\n----- STUDENT REPORT -----")
print("Name:", name)
print("Roll Number:", roll_no)
print("Maths:", maths)
print("Science:", science)
print("English:", english)
print("Computer:", computer)
print("Hindi:", hindi)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# Enter student name: Sonam
# Enter roll number: 196
# Enter Maths marks: 96
# Enter Science marks: 96
# Enter English marks: 84
# Enter Computer marks: 95
# Enter Hindi marks: 94
#
# ----- STUDENT REPORT -----
# Name: Sonam
# Roll Number: 196
# Maths: 96
# Science: 96
# English: 84
# Computer: 95
# Hindi: 94
# Total Marks: 465
# Percentage: 93.0 %
